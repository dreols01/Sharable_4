# %% [markdown]
# Does Race impact the number or kinds of powers a person might have?

# %%
import pandas as pd
import numpy as np
from dfply import *

Stats = pd.read_csv('./data/heroes_information.csv', na_values=['-', '-99.0', ''])
Hero_Powers = pd.read_csv('./data/super_hero_powers.csv')

# %%
Stats.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics        NaN      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics        NaN       bad   441.0
# 4     NaN      Marvel Comics        NaN       bad     NaN

# %%
Powers = (Hero_Powers
>> mutate(name = X.hero_names)
>> drop(X.hero_names))

Powers.head()
# Out:
#    Agility  Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0     True                False               False                  False
# 1    False                 True               False                  False
# 2     True                 True               False                  False
# 3    False                False                True                  False
# 4    False                 True               False                  False
#
#    Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0            False       False    False              False   False
# 1            False        True    False              False   False
# 2             True        True    False              False   False
# 3            False       False    False              False   False
# 4            False       False    False              False   False
#
#    Danger Sense  ...  Reality Warping  Odin Force  Symbiote Costume  \
# ...

# %%
dict_converter = {'True' : 1, 
    'False' : 0}

# %%
from more_dfply import *
Powers_recoded = (Powers
>> gather('Power', 'Response', columns_from('Agility'))
# >> mutate(Power_Response =  (X.Response.map(dict_converter),
>> distinct
)
Powers_recoded.head(50)
# Out:
#                        Power Response
# 0                    Agility     True
# 1                    Agility    False
# 667      Accelerated Healing    False
# 668      Accelerated Healing     True
# 1334      Lantern Power Ring    False
# 1337      Lantern Power Ring     True
# 2001   Dimensional Awareness    False
# 2006   Dimensional Awareness     True
# 2668         Cold Resistance    False
# 2670         Cold Resistance     True
# 3335              Durability    False
# 3336              Durability     True
# 4002                 Stealth    False
# 4010                 Stealth     True
# 4669       Energy Absorption    False
# 4675       Energy Absorption     True
# 5336                  Flight    False
# 5341                  Flight     True
# 6003            Danger Sense    False
# 6016            Danger Sense     True
# 6670    Underwater breathing    False
# 6672    Underwater breathing     True
# 7337            Marksmanship    False
# 7339            Marksmanship     True
# ...
